# %% [markdown]
# # Airfoil Self-Noise

# %% [markdown]
# Dataset Link : https://archive.ics.uci.edu/ml/datasets/Airfoil+Self-Noise

# %% [raw]
# This problem has the following inputs:
# 1. Frequency, in Hertz.
# 2. Angle of attack, in degrees.
# 3. Chord length, in meters.
# 4. Free-stream velocity, in meters per second.
# 5. Suction side displacement thickness, in meters.
#
# The only output is:
# 6. Scaled sound pressure level, in decibels.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("airfoil_self_noise.dat",sep="\t",header=None)

# %%
data.tail()
# Out:
#          0     1       2     3         4        5
# 1498  2500  15.6  0.1016  39.6  0.052849  110.264
# 1499  3150  15.6  0.1016  39.6  0.052849  109.254
# 1500  4000  15.6  0.1016  39.6  0.052849  106.604
# 1501  5000  15.6  0.1016  39.6  0.052849  106.224
# 1502  6300  15.6  0.1016  39.6  0.052849  104.204

# %%
data.columns = ['Frequency','Angle','Chord Length','Free-Stream Velocity','Thickness','Pressure Level']

# %%
data.head()
# Out:
#    Frequency  Angle  Chord Length  Free-Stream Velocity  Thickness  \
# 0        800    0.0        0.3048                  71.3   0.002663
# 1       1000    0.0        0.3048                  71.3   0.002663
# 2       1250    0.0        0.3048                  71.3   0.002663
# 3       1600    0.0        0.3048                  71.3   0.002663
# 4       2000    0.0        0.3048                  71.3   0.002663
#
#    Pressure Level
# 0         126.201
# 1         125.201
# 2         125.951
# 3         127.591
# 4         127.461

# %% [markdown]
# ## Data Visualization

# %%
sns.distplot(data['Frequency'],bins=40)

# %%
sns.distplot(data['Angle'],bins=40,kde=False)

# %%
sns.distplot(data['Chord Length'],bins=40,kde=False)

# %%
sns.distplot(data['Free-Stream Velocity'],bins=40,kde=False)

# %%
sns.distplot(data['Thickness'],bins=40)

# %%
sns.scatterplot(x='Frequency',y='Pressure Level',data=data)

# %%
sns.scatterplot(x='Angle',y='Pressure Level',data=data)

# %%
sns.scatterplot(x='Chord Length',y='Pressure Level',data=data)

# %% [markdown]
# ## Spliting Training and Testing Data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(data.drop('Pressure Level',axis=1),data['Pressure Level'],test_size=0.3)

# %% [markdown]
# ## Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg = LinearRegression()

# %%
linreg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pred = linreg.predict(X_test)

# %% [markdown]
# ## Evaluating

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
print("Mean Absolute error: ",mean_absolute_error(y_test,pred))
print("Mean Squared error: ",mean_squared_error(y_test,pred))
print("Root Mean Squared error: ",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Mean Absolute error:  3.838997375024488
# Mean Squared error:  23.940145167167618
# Root Mean Squared error:  4.892866763684417
